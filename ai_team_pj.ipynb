# %% [markdown]
# ## Introduction to Artificial Intelligence
# ### Program: Photo recognition && return accuracy, name, calorie
# #### TEAM #:
# #### NAME: Kang Harim(20),
# Description: -
# 역할 분배 예상
# REPORT&PPT(1(+1)), MODEL DEVELOP(1(+1)), PRESENTATION&PPT(1)
# **다음주 중으로 만나기**

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (22.1.1)
# Collecting pip
#   Downloading pip-22.1.2-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 3.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.1.1
#     Uninstalling pip-22.1.1:
#       Successfully uninstalled pip-22.1.1
# Successfully installed pip-22.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install flickrapi
# Out:
# Requirement already satisfied: flickrapi in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (2.4.0)
# Requirement already satisfied: requests>=2.2.1 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from flickrapi) (2.26.0)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from flickrapi) (1.3.1)
# Requirement already satisfied: requests-toolbelt>=0.3.1 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from flickrapi) (0.9.1)
# Requirement already satisfied: six>=1.5.2 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from flickrapi) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.2.1->flickrapi) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.2.1->flickrapi) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.2.1->flickrapi) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.2.1->flickrapi) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.4.0->flickrapi) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from flickrapi import FlickrAPI
from urllib.request import urlretrieve
from pprint import pprint
import os, time, sys

#AP key
key="f80929de7d2ad863fe7a549666f51ac7"
secret="050a4836eedd6ab7"
wait_time=1

def main():
#     go_download('초밥','sushi')
#     go_download('샐러드','salad')
#     go_download('피자','pizza')
#     go_download('떡볶이','tteokbokki')
#     go_download('김밥','kimbap')
#     go_download('짜장면','jjajangmyeon')
#     go_download('햄버거','hamburger')
#     go_download('파스타','pasta')
    go_download('돈까스','tonkatsu')
    
def go_download(keyword, dir):
    savedir="./image/"+dir
    if not os.path.exists(savedir):
        os.mkdir(savedir)
    flickr=FlickrAPI(key,secret,format='parsed-json')
    res=flickr.photos.search(
    text=keyword,
    per_page=300,
    media='photos',
    sort = "relevance",
        safe_search = 1,
        extras = 'url_q, license')
    
    photos = res['photos']
    pprint(photos)
    
    try:
        for i, photo in enumerate(photos['photo']):
            url_q = photo['url_q']
            filepath = savedir + '/' + photo['id'] + ".jpg"
            if os.path.exists(filepath): continue
            print(str(i+1) + ":download=", url_q)
            urlretrieve(url_q,filepath)
            time.sleep(wait_time)
    except:
        import traceback
        traceback.print_exc()
    
if __name__ == '__main__':
    main()
# Out:
#   File "/var/folders/r_/0hvkbwb17c18rb90k199y_f40000gn/T/ipykernel_16501/2170600776.py", line 22
#     def go_download(keyword, dir):
#     ^
# IndentationError: expected an indented block

# %%
import numpy as np
from PIL import Image
import os, glob, random

outfile = "image/photos.npz"
max_photo = 200
photo_size = 128
x = []
y = []

def main():
    glob_files("./image/sushi",0)
    glob_files("./image/salad",1)
    glob_files("./image/pizza",2)
    glob_files("./image/tteokbokki",3)
    glob_files("./image/kimbap",4)
    glob_files("./image/jjajang",5)
    glob_files("./image/hamburger",6)
    glob_files("./image/pasta",7)
    glob_files("./image/tonkatsu",8)
    
    np.savez(outfile, x=x, y=y)
    print("저장했습니다.:" + outfile, len(x))
    
def glob_files(path, label):
    files = glob.glob(path + "/*.jpg")
    random.shuffle(files)
    
    num = 0 
    for f in files:
        if num >= max_photo: break
        num += 1
        
        img = Image.open(f)
        img = img.convert("RGB")
        img = img.resize((photo_size, photo_size))
        img = np.asarray(img)
        x.append(img)
        y.append(label)

if __name__ == '__main__':
    main()
# Out:
# 저장했습니다.:image/photos.npz 1504

# %%
import matplotlib.pyplot as plt
# 사진 데이터 읽어 들이기
photos=np.load('image/photos.npz')
x=photos['x']
y=photos['y']
idx=0
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.title(y[i+idx])
    plt.imshow(x[i+idx])
plt.show()

# %%
# !pip install keras
# !pip install kears.models
# !pip install kears.layers
# !pip install kears.optimizers

# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (2.9.1)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (21.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.12)
# Requirement already satisfied: six>=1.12.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.46.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: numpy>=1.20 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.20.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: setuptools in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.3.7)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.6.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.0.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.26.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from packaging->tensorflow) (3.0.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.8.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.7)
# Requirement already satisfied: zipp>=0.5 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import RMSprop

# CNN 모델 정의하기
def def_model(in_shape, nb_classes):
    model=Sequential()
    model.add(Conv2D(64,
                    kernel_size=(3,3),
                    activation='relu',
                    input_shape=in_shape))
    #model.add(Conv2D(64,(3,3),activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))
    
    #model.add(Conv2D(256,(3,3),activation='relu'))
    model.add(Conv2D(256,(3,3),activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))
    
    model.add(Flatten())
    model.add(Dense(512,activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(nb_classes,activation='softmax'))
    return model

# %%
# compile & return model
def get_model(in_shape, nb_classes):
    model=def_model(in_shape,nb_classes)
    model.compile(
        loss='categorical_crossentropy',
        optimizer=RMSprop(),
        metrics=['accuracy'])
    return model

# %%
# import cnn_model
import keras
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

im_rows=128
im_cols=128
im_color=3
in_shape=(im_rows,im_cols,im_color)
nb_classes=9

photos=np.load('image/photos.npz')
x=photos['x']
y=photos['y']

x=x.reshape(-1,im_rows,im_cols,im_color)
x=x.astype('float32')/255
y=keras.utils.np_utils.to_categorical(y.astype('int32'),nb_classes)
print(x.shape)
print(y.shape)

x_train, x_test, y_train, y_test=train_test_split(
x,y,train_size=0.8)

# CNN model 만들기
model=get_model(in_shape,nb_classes)

hist=model.fit(x_train,y_train,
               batch_size=32,
               epochs=30,
               verbose=1,
               validation_data=(x_test,y_test)
              )

score=model.evaluate(x_test,y_test,verbose=1)
print('정답률=',score[1],'손실률=',score[0])
# Out:
# (1504, 128, 128, 3)
# (1504, 9)
# Epoch 1/30
# 38/38 [==============================] - 150s 4s/step - loss: 6.1785 - accuracy: 0.1879 - val_loss: 2.0339 - val_accuracy: 0.2093
# Epoch 2/30
# 38/38 [==============================] - 136s 4s/step - loss: 1.9468 - accuracy: 0.2751 - val_loss: 1.9285 - val_accuracy: 0.2458
# Epoch 3/30
# 38/38 [==============================] - 207s 6s/step - loss: 1.7411 - accuracy: 0.3732 - val_loss: 1.9339 - val_accuracy: 0.2359
# Epoch 4/30
# 38/38 [==============================] - 181s 5s/step - loss: 1.4061 - accuracy: 0.5220 - val_loss: 2.0403 - val_accuracy: 0.2326
# Epoch 5/30
# 38/38 [==============================] - 202s 5s/step - loss: 0.9172 - accuracy: 0.6974 - val_loss: 1.9862 - val_accuracy: 0.3023
# Epoch 6/30
# 38/38 [==============================] - 156s 4s/step - loss: 0.5373 - accuracy: 0.8387 - val_loss: 2.6542 - val_accuracy: 0.3023
# Epoch 7/30
# 38/38 [==============================] - 137s 4s/step - loss: 0.3422 - accuracy: 0.8961 - val_loss: 2.9490 - val_accuracy: 0.2857
# Epoch 8/30
# 38/38 [==============================] - 141s 4s/step - loss: 0.2684 - accuracy: 0.9327 - val_loss: 3.2253 - val_accuracy: 0.3123
# Epoch 9/30
# 38/38 [==============================] - 112s 3s/step - loss: 0.1613 - accuracy: 0.9651 - val_loss: 3.0840 - val_accuracy: 0.2957
# Epoch 10/30
# 38/38 [==============================] - 114s 3s/step - loss: 0.2323 - accuracy: 0.9692 - val_loss: 3.8446 - val_accuracy: 0.2924
# Epoch 11/30
# 38/38 [==============================] - 160s 4s/step - loss: 0.0748 - accuracy: 0.9859 - val_loss: 4.4821 - val_accuracy: 0.2957
# Epoch 12/30
# 38/38 [==============================] - 137s 4s/step - loss: 0.0506 - accuracy: 0.9875 - val_loss: 5.0424 - val_accuracy: 0.2957
# Epoch 13/30
# 38/38 [==============================] - 130s 3s/step - loss: 0.3264 - accuracy: 0.9601 - val_loss: 4.1863 - val_accuracy: 0.3090
# Epoch 14/30
# 38/38 [==============================] - 132s 3s/step - loss: 0.0284 - accuracy: 0.9925 - val_loss: 4.8049 - val_accuracy: 0.2824
# Epoch 15/30
# 38/38 [==============================] - 147s 4s/step - loss: 0.0502 - accuracy: 0.9900 - val_loss: 5.0248 - val_accuracy: 0.2890
# Epoch 16/30
# 38/38 [==============================] - 143s 4s/step - loss: 0.2415 - accuracy: 0.9709 - val_loss: 5.0218 - val_accuracy: 0.2857
# Epoch 17/30
# 38/38 [==============================] - 213s 6s/step - loss: 0.0359 - accuracy: 0.9958 - val_loss: 5.2305 - val_accuracy: 0.2591
# Epoch 18/30
# 38/38 [==============================] - 202s 5s/step - loss: 0.0258 - accuracy: 0.9942 - val_loss: 10.1893 - val_accuracy: 0.2724
# Epoch 19/30
# 38/38 [==============================] - 199s 5s/step - loss: 0.0616 - accuracy: 0.9884 - val_loss: 6.0920 - val_accuracy: 0.2990
# Epoch 20/30
# 38/38 [==============================] - 176s 5s/step - loss: 0.0454 - accuracy: 0.9917 - val_loss: 6.5606 - val_accuracy: 0.2957
# Epoch 21/30
# 38/38 [==============================] - 160s 4s/step - loss: 0.0485 - accuracy: 0.9933 - val_loss: 7.3985 - val_accuracy: 0.2791
# Epoch 22/30
# 38/38 [==============================] - 135s 4s/step - loss: 0.0569 - accuracy: 0.9925 - val_loss: 6.1420 - val_accuracy: 0.2957
# Epoch 23/30
# 38/38 [==============================] - 178s 5s/step - loss: 0.0394 - accuracy: 0.9950 - val_loss: 6.3024 - val_accuracy: 0.3023
# Epoch 24/30
# 38/38 [==============================] - 226s 6s/step - loss: 0.0251 - accuracy: 0.9967 - val_loss: 3.9803 - val_accuracy: 0.2392
# Epoch 25/30
# 38/38 [==============================] - 147s 4s/step - loss: 0.1016 - accuracy: 0.9850 - val_loss: 5.6533 - val_accuracy: 0.3123
# Epoch 26/30
# 38/38 [==============================] - 149s 4s/step - loss: 0.0108 - accuracy: 0.9983 - val_loss: 6.6071 - val_accuracy: 0.2857
# Epoch 27/30
# 38/38 [==============================] - 107s 3s/step - loss: 0.0586 - accuracy: 0.9892 - val_loss: 6.2874 - val_accuracy: 0.2890
# Epoch 28/30
# 38/38 [==============================] - 109s 3s/step - loss: 0.0254 - accuracy: 0.9967 - val_loss: 6.7776 - val_accuracy: 0.3189
# Epoch 29/30
# 38/38 [==============================] - 122s 3s/step - loss: 0.0588 - accuracy: 0.9917 - val_loss: 6.7378 - val_accuracy: 0.2658
# Epoch 30/30
# 38/38 [==============================] - 152s 4s/step - loss: 0.0361 - accuracy: 0.9950 - val_loss: 6.1791 - val_accuracy: 0.2957
# 10/10 [==============================] - 11s 1s/step - loss: 6.1791 - accuracy: 0.2957
# 정답률= 0.29568105936050415 손실률= 6.179065704345703

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train','test'],loc='upper left')
plt.show()


plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train','test'],loc='upper left')
plt.show()

model.save_weights('./image/photos-model-light.hdf5')

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (4.5.5.64)
# Requirement already satisfied: numpy>=1.19.3 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from opencv-python) (1.20.3)

# %%
import matplotlib.pyplot as plt
import cv2

photos = np.load('image/photos.npz')
x = photos['x']
img = x[12]

plt.figure(figsize= (10,10))
for i in range(36):
    plt.subplot(6,6,i+1)

    center = (im_rows/2,im_cols/2)
    angle = i * 5
    scale = 1.0
    mtx = cv2.getRotationMatrix2D(center, angle, scale)
    img2 = cv2.warpAffine(img, mtx, (0,0))
    
    plt.imshow(img2)
plt.show()

# %%
import cv2

x_train, x_test, y_train, y_test = train_test_split( x, y, train_size=0.8)

x_new = []
y_new = []

for i, xi in enumerate(x_train):
    yi = y_train[i]
    for ang in range(-30, 30, 5):
        center = (im_rows/2,im_cols/2)
        mtx = cv2.getRotationMatrix2D(center, ang, 1.0)
        xi2 = cv2.warpAffine(xi, mtx, (0, 0))
        x_new.append(xi2)
        y_new.append(yi)
        
        xi3 = cv2.flip(xi2, 1)

print('수량 늘리기 전 = ', len(y_train) )
x_train = np.array(x_new)
y_train = np.array(y_new)
print('수량을 늘린 후 = ', len(y_train))

model = get_model(in_shape, nb_classes)
# Out:
# 수량 늘리기 전 =  1203
# 수량을 늘린 후 =  14436

# %%
# import cnn_model
import keras
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

target_image = "test-sushi.jgp"

im_rows = 128
im_cols = 128
im_color = 3
in_shape = (im_rows, im_cols, im_color)
nb_classes = 9
    
LABELS = ["초밥", "샐러드", "피자", "떡볶이", "김밥", "짜장면", "햄버거", "파스타", "돈까스"]

CALORIES = [588, 118, 266, 300, 485, 864, 294, 131, 574]

model = get_model(in_shape, nb_classes)
model.load_weights('./image/photos-model-light.hdf5')

def check_photo(path):
    img = Image.open(path)
    img = img.convert("RGB")
    print(img.size)
    img = img.resize((im_cols, im_rows))
    print(img.size)
    plt.imshow(img)
    plt.show()
    
    x = np.asarray(img)
    x = x.reshape(-1, im_rows, im_cols, im_color) 
    x = x/ 255
    
    pre = model.predict([x])[0]
    idx = pre.argmax()
    per = int(pre[idx]*100)
    return (idx, per)

def check_photo_str(path):
    idx, per = check_photo(path)
    
    print("이 사진은 ", LABELS[idx], "로(으로), 칼로리는 ", CALORIES[idx], "kcal 입니다.")
    print("정확도는 ", per , "% 입니다.")
    
if __name__ == '__main__':
    check_photo_str('./image/sushi/4001311474.jpg')
#     check_photo_str('test_salad.jpg')
# Out:
# (150, 150)
# (128, 128)
# 1/1 [==============================] - 0s 172ms/step
# 이 사진은  초밥 로(으로), 칼로리는  588 kcal 입니다.
# 정확도는  99 % 입니다.

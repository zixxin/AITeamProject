# %% [markdown]
# ## Introduction to Artificial Intelligence
# ### Program: Photo recognition && return accuracy, name, calorie
# #### TEAM #:
# #### NAME: Kang Harim(20),
# Description: -
# 역할 분배 예상
# REPORT&PPT(1(+1)), MODEL DEVELOP(1(+1)), PRESENTATION&PPT(1)
# **다음주 중으로 만나기**

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (21.2.4)
# Collecting pip
#   Downloading pip-22.1.1-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 1.6 MB/s eta 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# Successfully installed pip-22.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install flickrapi
# Out:
# Collecting flickrapi
#   Downloading flickrapi-2.4.0-py2.py3-none-any.whl (26 kB)
# Collecting requests-toolbelt>=0.3.1
#   Downloading requests_toolbelt-0.9.1-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 153.9 kB/s eta 0:00:00 0:00:01
# Collecting requests-oauthlib>=0.4.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: requests>=2.2.1 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from flickrapi) (2.26.0)
# Requirement already satisfied: six>=1.5.2 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from flickrapi) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.2.1->flickrapi) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.2.1->flickrapi) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.2.1->flickrapi) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.2.1->flickrapi) (2021.10.8)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.5/151.5 kB 505.2 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: oauthlib, requests-toolbelt, requests-oauthlib, flickrapi
# Successfully installed flickrapi-2.4.0 oauthlib-3.2.0 requests-oauthlib-1.3.1 requests-toolbelt-0.9.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from flickrapi import FlickrAPI
from urllib.request import urlretrieve
from pprint import pprint
import os, time, sys

#AP key
key="f80929de7d2ad863fe7a549666f51ac7"
secret="050a4836eedd6ab7"
wait_time=1

def main():
#     go_download('초밥','sushi')
#     go_download('샐러드','salad')
#     go_download('피자','pizza')
#     go_download('떡볶이','tteokbokki')
#     go_download('김밥','kimbap')
#     go_download('짜장면','jjajangmyeon')
#     go_download('햄버거','hamburger')
#     go_download('파스타','pasta')
    go_download('돈까스','tonkatsu')
    
def go_download(keyword, dir):
    savedir="./image/"+dir
    if not os.path.exists(savedir):
        os.mkdir(savedir)
    flickr=FlickrAPI(key,secret,format='parsed-json')
    res=flickr.photos.search(
    text=keyword,
    per_page=300,
    media='photos',
    sort = "relevance",
        safe_search = 1,
        extras = 'url_q, license')
    
    photos = res['photos']
    pprint(photos)
    
    try:
        for i, photo in enumerate(photos['photo']):
            url_q = photo['url_q']
            filepath = savedir + '/' + photo['id'] + ".jpg"
            if os.path.exists(filepath): continue
            print(str(i+1) + ":download=", url_q)
            urlretrieve(url_q,filepath)
            time.sleep(wait_time)
    except:
        import traceback
        traceback.print_exc()
    
if __name__ == '__main__':
    main()
# Out:
# {'page': 1,
#  'pages': 4,
#  'perpage': 300,
#  'photo': [{'farm': 8,
#             'height_q': 150,
#             'id': '6943991914',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '50154521@N08',
#             'secret': 'dffee4d83a',
#             'server': '7126',
#             'title': 'Food',
#             'url_q': 'https://live.staticflickr.com/7126/6943991914_dffee4d83a_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '40197909585',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': '548090ce37',
#             'server': '882',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/882/40197909585_548090ce37_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3310106503',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': '8901d96f78',
#             'server': '3441',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/3441/3310106503_8901d96f78_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8564760402',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '67347235@N00',
#             'secret': 'e7e46f56e6',
#             'server': '8523',
#             'title': '돈까스 김치볶음밥',
#             'url_q': 'https://live.staticflickr.com/8523/8564760402_e7e46f56e6_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '33596967415',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '28021450@N05',
#             'secret': 'dba38802db',
#             'server': '2813',
#             'title': '카쯔야 홍대점',
#             'url_q': 'https://live.staticflickr.com/2813/33596967415_dba38802db_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '11267638394',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '79382228@N08',
#             'secret': '23da5c822d',
#             'server': '7304',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/7304/11267638394_23da5c822d_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '33213954640',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '28021450@N05',
#             'secret': 'ef76230892',
#             'server': '3788',
#             'title': '카쯔야 홍대점',
#             'url_q': 'https://live.staticflickr.com/3788/33213954640_ef76230892_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '32783236093',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '28021450@N05',
#             'secret': 'f95fb38244',
#             'server': '3829',
#             'title': '카쯔야 홍대점',
#             'url_q': 'https://live.staticflickr.com/3829/32783236093_f95fb38244_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '32783238073',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '28021450@N05',
#             'secret': '5ceeff5dee',
#             'server': '2891',
#             'title': '카쯔야 홍대점',
#             'url_q': 'https://live.staticflickr.com/2891/32783238073_5ceeff5dee_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '7975737140',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '66859959@N02',
#             'secret': '7796d9f231',
#             'server': '8447',
#             'title': 'donkas',
#             'url_q': 'https://live.staticflickr.com/8447/7975737140_7796d9f231_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '33596968405',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '28021450@N05',
#             'secret': '6b0811873a',
#             'server': '2942',
#             'title': '카쯔야 홍대점',
#             'url_q': 'https://live.staticflickr.com/2942/33596968405_6b0811873a_q.jpg',
#             'width_q': 150},
#            {'farm': 66,
#             'height_q': 150,
#             'id': '52090263764',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': '39a6074276',
#             'server': '65535',
#             'title': '치즈로제소스 돈까스 Donkatsu',
#             'url_q': 'https://live.staticflickr.com/65535/52090263764_39a6074276_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '42036304052',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '28021450@N05',
#             'secret': '4e28f7178d',
#             'server': '904',
#             'title': '돈까스 오므라이스 카레',
#             'url_q': 'https://live.staticflickr.com/904/42036304052_4e28f7178d_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '30883555500',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '87936699@N06',
#             'secret': '88e10d31ac',
#             'server': '5321',
#             'title': 'Tonkatsu & Curry Rice Meals(Coco Ichibanya)',
#             'url_q': 'https://live.staticflickr.com/5321/30883555500_88e10d31ac_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '29807438905',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': '5f3a416c1d',
#             'server': '8340',
#             'title': '클래식 돈까스 Classical Tonkatsu',
#             'url_q': 'https://live.staticflickr.com/8340/29807438905_5f3a416c1d_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '41041242321',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '87936699@N06',
#             'secret': 'f97f347b55',
#             'server': '805',
#             'title': 'Japanese Tonkatsu & Curry',
#             'url_q': 'https://live.staticflickr.com/805/41041242321_f97f347b55_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '32640124321',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '87936699@N06',
#             'secret': 'cccb36d2ec',
#             'server': '591',
#             'title': 'Fried Rice & Shrimp(Prawn)',
#             'url_q': 'https://live.staticflickr.com/591/32640124321_cccb36d2ec_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4408015338',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '5',
#             'owner': '28021450@N05',
#             'secret': 'd0f30ecb7d',
#             'server': '4067',
#             'title': '결국 나는 돈까스 얹어진 오..',
#             'url_q': 'https://live.staticflickr.com/4067/4408015338_d0f30ecb7d_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '3938005396',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '40726522@N02',
#             'secret': '5b41e32686',
#             'server': '2512',
#             'title': 'Jja Jang Myun / Tonkatsu',
#             'url_q': 'https://live.staticflickr.com/2512/3938005396_5b41e32686_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4033724375',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '36613407@N02',
#             'secret': '17a4038b5a',
#             'server': '2762',
#             'title': '나름 강동의 맛집으로 꼽히는..',
#             'url_q': 'https://live.staticflickr.com/2762/4033724375_17a4038b5a_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '11198437773',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '28021450@N05',
#             'secret': '4ae435ee45',
#             'server': '5502',
#             'title': 'Very Sinjuku, 베리신주쿠 (대전 어은동)',
#             'url_q': 'https://live.staticflickr.com/5502/11198437773_4ae435ee45_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '44638451030',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '54112166@N08',
#             'secret': '6faa06ac18',
#             'server': '4821',
#             'title': '명동 돈까스 비싸',
#             'url_q': 'https://live.staticflickr.com/4821/44638451030_6faa06ac18_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6417708433',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '42730643@N05',
#             'secret': '31a4eab8cf',
#             'server': '7155',
#             'title': '점심 식사로 먹은 돈까스 얹..',
#             'url_q': 'https://live.staticflickr.com/7155/6417708433_31a4eab8cf_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '31054858601',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '22653804@N06',
#             'secret': 'edc2396e14',
#             'server': '5341',
#             'title': '오늘은 우동을 먹기로 했으니 돈까스 카레 우동',
#             'url_q': 'https://live.staticflickr.com/5341/31054858601_edc2396e14_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '4067925641',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '5',
#             'owner': '28021450@N05',
#             'secret': '102b05c610',
#             'server': '3533',
#             'title': '점심에 학교식당에서 먹은 돈..',
#             'url_q': 'https://live.staticflickr.com/3533/4067925641_102b05c610_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3952308749',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '10911825@N00',
#             'secret': 'cc07aa8294',
#             'server': '3426',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/3426/3952308749_cc07aa8294_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3026416415',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '87171883@N00',
#             'secret': 'ce26a85799',
#             'server': '3051',
#             'title': '오랜만에 돈까스',
#             'url_q': 'https://live.staticflickr.com/3051/3026416415_ce26a85799_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '7134472551',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '37934744@N02',
#             'secret': '743db80f88',
#             'server': '7100',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/7100/7134472551_743db80f88_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '38073756752',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28999666@N04',
#             'secret': '14d1bd7c0a',
#             'server': '4510',
#             'title': '돈까스 도시락 (2)',
#             'url_q': 'https://live.staticflickr.com/4510/38073756752_14d1bd7c0a_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3559055911',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '12656864@N08',
#             'secret': '819e9942cd',
#             'server': '3331',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/3331/3559055911_819e9942cd_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '171843973',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '82971493@N00',
#             'secret': 'dee9c38b16',
#             'server': '66',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/66/171843973_dee9c38b16_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4524779044',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11499044@N08',
#             'secret': '0a659f7212',
#             'server': '4003',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/4003/4524779044_0a659f7212_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4116680690',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '42807823@N08',
#             'secret': 'fc80bacf8d',
#             'server': '2542',
#             'title': '심바시 마루야의 돈까스 …...',
#             'url_q': 'https://live.staticflickr.com/2542/4116680690_fc80bacf8d_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4744209035',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11499044@N08',
#             'secret': '861024138a',
#             'server': '4134',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/4134/4744209035_861024138a_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4580415599',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '6',
#             'owner': '29180485@N07',
#             'secret': '189e69977c',
#             'server': '4064',
#             'title': '어린이날이니 돈까스먹으러',
#             'url_q': 'https://live.staticflickr.com/4064/4580415599_189e69977c_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6943991872',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '50154521@N08',
#             'secret': '32b734de34',
#             'server': '7110',
#             'title': 'Food',
#             'url_q': 'https://live.staticflickr.com/7110/6943991872_32b734de34_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5886299697',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '37934744@N02',
#             'secret': 'a5f42e68be',
#             'server': '5222',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/5222/5886299697_a5f42e68be_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '4727231150',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '26279340@N00',
#             'secret': '9c3e3f8cc4',
#             'server': '1248',
#             'title': '간만에 먹는 경양식(?) 돈..',
#             'url_q': 'https://live.staticflickr.com/1248/4727231150_9c3e3f8cc4_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4388807311',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11499044@N08',
#             'secret': '94d270ab32',
#             'server': '2735',
#             'title': 'pork cutlet',
#             'url_q': 'https://live.staticflickr.com/2735/4388807311_94d270ab32_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6324818622',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '37934744@N02',
#             'secret': '08050d91bb',
#             'server': '6033',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/6033/6324818622_08050d91bb_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4230570238',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '4',
#             'owner': '59658513@N00',
#             'secret': '66801b68d5',
#             'server': '2657',
#             'title': '2009년 최고의 맛집 “정..',
#             'url_q': 'https://live.staticflickr.com/2657/4230570238_66801b68d5_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6781197705',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '69329210@N02',
#             'secret': '2f44174835',
#             'server': '7174',
#             'title': '돈까스와 우동',
#             'url_q': 'https://live.staticflickr.com/7174/6781197705_2f44174835_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3465518760',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '26529769@N08',
#             'secret': '9d2da29ec3',
#             'server': '3607',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/3607/3465518760_9d2da29ec3_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2715814759',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '26529769@N08',
#             'secret': '5d02e91fcf',
#             'server': '3062',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/3062/2715814759_5d02e91fcf_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '14141913208',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '124008426@N08',
#             'secret': '1d1572a6e9',
#             'server': '5534',
#             'title': '가족즐 저녁외식#돈따스마마#화곡동#까지산역에서',
#             'url_q': 'https://live.staticflickr.com/5534/14141913208_1d1572a6e9_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8028386080',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '26920049@N02',
#             'secret': '932e87052e',
#             'server': '8317',
#             'title': '아흣 또 먹다가 생각났넹*-_-*',
#             'url_q': 'https://live.staticflickr.com/8317/8028386080_932e87052e_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4299594272',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '34072796@N04',
#             'secret': 'd197cbe402',
#             'server': '2763',
#             'title': '돈까스!!~♡',
#             'url_q': 'https://live.staticflickr.com/2763/4299594272_d197cbe402_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '4729565604',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '33772413@N02',
#             'secret': 'b80e9fc552',
#             'server': '1071',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/1071/4729565604_b80e9fc552_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6781210585',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '69329210@N02',
#             'secret': '8ec1901afc',
#             'server': '7155',
#             'title': '돈코츠덮밥',
#             'url_q': 'https://live.staticflickr.com/7155/6781210585_8ec1901afc_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3239071888',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '33963312@N00',
#             'secret': '8dd7056a48',
#             'server': '3525',
#             'title': 'King pork cutlet :-)',
#             'url_q': 'https://live.staticflickr.com/3525/3239071888_8dd7056a48_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4744208735',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11499044@N08',
#             'secret': '51c22ec23c',
#             'server': '4102',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/4102/4744208735_51c22ec23c_q.jpg',
#             'width_q': 150},
#            {'farm': 66,
#             'height_q': 150,
#             'id': '50431998942',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': '7b5e3c868c',
#             'server': '65535',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/65535/50431998942_7b5e3c868c_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4398162092',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7338778@N07',
#             'secret': '1b92e6794b',
#             'server': '4010',
#             'title': '금왕돈까스. 본점은 넘 멀어..',
#             'url_q': 'https://live.staticflickr.com/4010/4398162092_1b92e6794b_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '3895528314',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '36394973@N04',
#             'secret': '401c8e21de',
#             'server': '2575',
#             'title': '삼계탕집와서 돈까스주세요~',
#             'url_q': 'https://live.staticflickr.com/2575/3895528314_401c8e21de_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2691782405',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28682831@N03',
#             'secret': '2f749a629d',
#             'server': '3261',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/3261/2691782405_2f749a629d_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '3926383184',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '47502209@N00',
#             'secret': '0c8695a331',
#             'server': '2476',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/2476/3926383184_0c8695a331_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5527489077',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11499044@N08',
#             'secret': '2eb08cd340',
#             'server': '5258',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/5258/5527489077_2eb08cd340_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2507776620',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': '3996928c73',
#             'server': '3007',
#             'title': '험악한 동네 분식집 스페셜 메뉴',
#             'url_q': 'https://live.staticflickr.com/3007/2507776620_3996928c73_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5531824597',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '19175143@N00',
#             'secret': '3728c373b3',
#             'server': '5296',
#             'title': '월드 돈까스',
#             'url_q': 'https://live.staticflickr.com/5296/5531824597_3728c373b3_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '5184294388',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '23620468@N03',
#             'secret': 'e1a1aca04a',
#             'server': '1427',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/1427/5184294388_e1a1aca04a_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '14492215572',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '124704109@N06',
#             'secret': '94edf161fe',
#             'server': '3916',
#             'title': '20140614_190323',
#             'url_q': 'https://live.staticflickr.com/3916/14492215572_94edf161fe_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '21486927865',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '129837995@N02',
#             'secret': '5a17d9d3c1',
#             'server': '5762',
#             'title': '',
#             'url_q': 'https://live.staticflickr.com/5762/21486927865_5a17d9d3c1_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4059828742',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '44248278@N08',
#             'secret': 'b7eaa57b5b',
#             'server': '2516',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/2516/4059828742_b7eaa57b5b_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '1385677759',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '12392289@N04',
#             'secret': '63e2a0c75c',
#             'server': '1423',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/1423/1385677759_63e2a0c75c_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2997234751',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '31638263@N06',
#             'secret': 'ae95282818',
#             'server': '3205',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/3205/2997234751_ae95282818_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '33830919012',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '34642865@N08',
#             'secret': 'b79808d5ca',
#             'server': '2946',
#             'title': '20170412_144938',
#             'url_q': 'https://live.staticflickr.com/2946/33830919012_b79808d5ca_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2778058403',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '29692140@N07',
#             'secret': 'd1698ce5b0',
#             'server': '3050',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/3050/2778058403_d1698ce5b0_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4613658025',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '42725448@N07',
#             'secret': 'd2ef714df7',
#             'server': '4036',
#             'title': '목석원 앞 “배터지는 생동까..',
#             'url_q': 'https://live.staticflickr.com/4036/4613658025_d2ef714df7_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '8751636711',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '79382228@N08',
#             'secret': '5192cbf910',
#             'server': '5331',
#             'title': '돈까스!',
#             'url_q': 'https://live.staticflickr.com/5331/8751636711_5192cbf910_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6938072789',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '75574154@N07',
#             'secret': 'a2b27b15ff',
#             'server': '7064',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/7064/6938072789_a2b27b15ff_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '21847822211',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '134844837@N03',
#             'secret': '69b8ef7b69',
#             'server': '694',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/694/21847822211_69b8ef7b69_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '8152784535',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '65954914@N04',
#             'secret': '98e73a773a',
#             'server': '7125',
#             'title': '돈까스',
#             'url_q': 'https://live.staticflickr.com/7125/8152784535_98e73a773a_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '14218126501',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '10490729@N02',
#             'secret': '7192e023e2',
#             'server': '2934',
#             'title': '돈까스 - SDIM4421',
#             'url_q': 'https://live.staticflickr.com/2934/14218126501_7192e023e2_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4456457764',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '36961744@N05',
#             'secret': '4bfc378a50',
#             'server': '4027',
#             'title': '오늘 점심은 돈까스+함박스테..',
#             'url_q': 'https://live.staticflickr.com/4027/4456457764_4bfc378a50_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '7453009796',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '79647956@N03',
#             'secret': '734bf92cbc',
#             'server': '8156',
#             'title': '왕 돈까스',
#             'url_q': 'https://live.staticflickr.com/8156/7453009796_734bf92cbc_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4388928974',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '97502594@N00',
#             'secret': '7d701352e1',
#             'server': '2768',
#             'title': '명동 돈까스',
#             'url_q': 'https://live.staticflickr.com/2768/4388928974_7d701352e1_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6962322770',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '78691191@N02',
#             'secret': '543ddc34cf',
#             'server': '7228',
#             'title': '우동과 돈까스',
#             'url_q': 'https://live.staticflickr.com/7228/6962322770_543ddc34cf_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2735479684',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '29198495@N04',
#             'secret': '633fb1162c',
#             'server': '3258',
#             'title': '드디어 나온 돈까스... +..',
#             'url_q': 'https://live.staticflickr.com/3258/2735479684_633fb1162c_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8419787896',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '79839352@N08',
#             'secret': '0b37652f26',
#             'server': '8074',
#             'title': '명동 돈까스',
#             'url_q': 'https://live.staticflickr.com/8074/8419787896_0b37652f26_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2760053244',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28853050@N04',
#             'secret': '9a895e9359',
#             'server': '3032',
#             'title': '와플에 돈까스',
#             'url_q': 'https://live.staticflickr.com/3032/2760053244_9a895e9359_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8112272610',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '46130640@N05',
#             'secret': '0e7b8fcbdd',
#             'server': '8327',
#             'title': '오랫만에 기사식당풍 돈까스~ㅎ',
#             'url_q': 'https://live.staticflickr.com/8327/8112272610_0e7b8fcbdd_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4522586245',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '97502594@N00',
#             'secret': '9c14c99c0d',
#             'server': '4060',
#             'title': 'Breaded Lemon Chicken. Saboten.',
#             'url_q': 'https://live.staticflickr.com/4060/4522586245_9c14c99c0d_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '13557274675',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '28021450@N05',
#             'secret': '0606b48775',
#             'server': '3761',
#             'title': '연남동 향미 돈까스',
#             'url_q': 'https://live.staticflickr.com/3761/13557274675_0606b48775_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '7076259523',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '8429795@N05',
#             'secret': '26930bc609',
#             'server': '7190',
#             'title': '돈까스 같지만 아니에요',
#             'url_q': 'https://live.staticflickr.com/7190/7076259523_26930bc609_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '7478237456',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '79647956@N03',
#             'secret': 'e233a6b434',
#             'server': '8145',
#             'title': '돈까스 클럽',
#             'url_q': 'https://live.staticflickr.com/8145/7478237456_e233a6b434_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '29007293708',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '95331993@N06',
#             'secret': 'b3e7d38d50',
#             'server': '1742',
#             'title': 'Korean Pork Cutlet.',
#             'url_q': 'https://live.staticflickr.com/1742/29007293708_b3e7d38d50_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '7836836816',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '33766590@N02',
#             'secret': 'b358a4852e',
#             'server': '8287',
#             'title': '내 돈까스',
#             'url_q': 'https://live.staticflickr.com/8287/7836836816_b358a4852e_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2302240086',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '8055436@N08',
#             'secret': 'ac6e74b7a0',
#             'server': '2322',
#             'title': '핏자돈. 슈림프골드. 새우 ..',
#             'url_q': 'https://live.staticflickr.com/2322/2302240086_ac6e74b7a0_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4367626928',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '27097317@N00',
#             'secret': '8ec4ddcbc9',
#             'server': '4031',
#             'title': '저녁은 후레쉬빌 정식',
#             'url_q': 'https://live.staticflickr.com/4031/4367626928_8ec4ddcbc9_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '26814578645',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '50154521@N08',
#             'secret': '45672811a5',
#             'server': '7763',
#             'title': 'Food',
#             'url_q': 'https://live.staticflickr.com/7763/26814578645_45672811a5_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4489035359',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '55871012@N00',
#             'secret': 'bb9d4158ae',
#             'server': '4028',
#             'title': '헤비급 돈까스',
#             'url_q': 'https://live.staticflickr.com/4028/4489035359_bb9d4158ae_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4506974005',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '8429795@N05',
#             'secret': '8fe2557df7',
#             'server': '2764',
#             'title': '감동해 여기 올때마다 무려 ..',
#             'url_q': 'https://live.staticflickr.com/2764/4506974005_8fe2557df7_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '33674217675',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '28021450@N05',
#             'secret': '67872173db',
#             'server': '3956',
#             'title': '대만 돈까스',
#             'url_q': 'https://live.staticflickr.com/3956/33674217675_67872173db_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '33294217322',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': 'b51c052f3a',
#             'server': '658',
#             'title': '돈까스 Donkatsu',
#             'url_q': 'https://live.staticflickr.com/658/33294217322_b51c052f3a_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3406588128',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '44124301123@N01',
#             'secret': '771e6d52c3',
#             'server': '3545',
#             'title': '할아버지 돈까스',
#             'url_q': 'https://live.staticflickr.com/3545/3406588128_771e6d52c3_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2836917402',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '30255546@N02',
#             'secret': '1d60746987',
#             'server': '3057',
#             'title': 'Korean Food: 돈까스',
#             'url_q': 'https://live.staticflickr.com/3057/2836917402_1d60746987_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4253423293',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '36877757@N05',
#             'secret': 'd52fd2aedb',
#             'server': '4035',
#             'title': '손이 작아보이게 만드는 카츠..',
#             'url_q': 'https://live.staticflickr.com/4035/4253423293_d52fd2aedb_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6798251455',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11238204@N08',
#             'secret': '79b89db05f',
#             'server': '7028',
#             'title': '돈까스 2012',
#             'url_q': 'https://live.staticflickr.com/7028/6798251455_79b89db05f_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5276905146',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '54687792@N06',
#             'secret': 'f5894800f8',
#             'server': '5168',
#             'title': '하트 돈까스',
#             'url_q': 'https://live.staticflickr.com/5168/5276905146_f5894800f8_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '5820944184',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '88776513@N00',
#             'secret': 'b28d8766f6',
#             'server': '2544',
#             'title': '김밥천국 - 돈까스 김치 김밥',
#             'url_q': 'https://live.staticflickr.com/2544/5820944184_b28d8766f6_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '7080508431',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '78691191@N02',
#             'secret': '356937c6b8',
#             'server': '7200',
#             'title': '일본식 돈까스 세트메뉴',
#             'url_q': 'https://live.staticflickr.com/7200/7080508431_356937c6b8_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '5142518798',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '10290902@N05',
#             'secret': '8384f8bc2e',
#             'server': '1171',
#             'title': '돈까스 덮밥',
#             'url_q': 'https://live.staticflickr.com/1171/5142518798_8384f8bc2e_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6580659015',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '10290902@N05',
#             'secret': '669f53eacc',
#             'server': '7017',
#             'title': '북촌 돈까스',
#             'url_q': 'https://live.staticflickr.com/7017/6580659015_669f53eacc_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '44103475444',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '95331993@N06',
#             'secret': 'd2bcd6f3b5',
#             'server': '1849',
#             'title': 'Convenient Store Lunch Box.',
#             'url_q': 'https://live.staticflickr.com/1849/44103475444_d2bcd6f3b5_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4296065853',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '30008692@N05',
#             'secret': '4d61c86c73',
#             'server': '2750',
#             'title': '범섭님과 나루터님과 함께. ..',
#             'url_q': 'https://live.staticflickr.com/2750/4296065853_4d61c86c73_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2592785518',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '15134851@N00',
#             'secret': 'a9238d0db9',
#             'server': '3133',
#             'title': '돈까스 카레덮밥 (^(**)..',
#             'url_q': 'https://live.staticflickr.com/3133/2592785518_a9238d0db9_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4591166652',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '6',
#             'owner': '9179502@N07',
#             'secret': 'c9bbdb2593',
#             'server': '4063',
#             'title': '오늘 점심은 아내가 비빔밥을..',
#             'url_q': 'https://live.staticflickr.com/4063/4591166652_c9bbdb2593_q.jpg',
# ...
# 94:download= https://live.staticflickr.com/658/33294217322_b51c052f3a_q.jpg
# 95:download= https://live.staticflickr.com/3545/3406588128_771e6d52c3_q.jpg
# 96:download= https://live.staticflickr.com/3057/2836917402_1d60746987_q.jpg
# 97:download= https://live.staticflickr.com/4035/4253423293_d52fd2aedb_q.jpg
# 98:download= https://live.staticflickr.com/7028/6798251455_79b89db05f_q.jpg
# 99:download= https://live.staticflickr.com/5168/5276905146_f5894800f8_q.jpg
# 100:download= https://live.staticflickr.com/2544/5820944184_b28d8766f6_q.jpg
# 101:download= https://live.staticflickr.com/7200/7080508431_356937c6b8_q.jpg
# 102:download= https://live.staticflickr.com/1171/5142518798_8384f8bc2e_q.jpg
# 103:download= https://live.staticflickr.com/7017/6580659015_669f53eacc_q.jpg
# 104:download= https://live.staticflickr.com/1849/44103475444_d2bcd6f3b5_q.jpg
# 105:download= https://live.staticflickr.com/2750/4296065853_4d61c86c73_q.jpg
# 106:download= https://live.staticflickr.com/3133/2592785518_a9238d0db9_q.jpg
# 107:download= https://live.staticflickr.com/4063/4591166652_c9bbdb2593_q.jpg
# 108:download= https://live.staticflickr.com/4143/4817455202_213e7e15d4_q.jpg
# 109:download= https://live.staticflickr.com/7092/7306316206_37e897e831_q.jpg
# 110:download= https://live.staticflickr.com/3039/3018489559_6ef9699e4d_q.jpg
# 111:download= https://live.staticflickr.com/7240/7199898160_ebb09c9fe3_q.jpg
# 112:download= https://live.staticflickr.com/65535/49821581427_8b5930f05e_q.jpg
# 113:download= https://live.staticflickr.com/8218/29489633972_69d8ef2b93_q.jpg
# 114:download= https://live.staticflickr.com/3288/2357196212_8521014fe0_q.jpg
# 115:download= https://live.staticflickr.com/4073/4889683241_d33c5bbe4c_q.jpg
# 116:download= https://live.staticflickr.com/3088/2421758123_2887a2f566_q.jpg
# 117:download= https://live.staticflickr.com/4061/4440081688_2d14f8e335_q.jpg
# 118:download= https://live.staticflickr.com/4137/4887956382_7f4a783cdf_q.jpg
# 119:download= https://live.staticflickr.com/5178/5528079896_e9413cc27c_q.jpg
# 120:download= https://live.staticflickr.com/5226/5616274442_96fccd811d_q.jpg
# 121:download= https://live.staticflickr.com/2754/4265524164_1615b7bc16_q.jpg
# 122:download= https://live.staticflickr.com/8144/7185437623_41e4dd41d2_q.jpg
# 123:download= https://live.staticflickr.com/3282/2552887108_271d351ed9_q.jpg
# 124:download= https://live.staticflickr.com/6124/6005029567_56dd515507_q.jpg
# 125:download= https://live.staticflickr.com/975/28319195718_3a8a748429_q.jpg
# 126:download= https://live.staticflickr.com/4046/4591224832_2a30fb69cf_q.jpg
# 127:download= https://live.staticflickr.com/5009/5228163458_980975d57c_q.jpg
# 128:download= https://live.staticflickr.com/3244/2425206984_1d98548392_q.jpg
# 129:download= https://live.staticflickr.com/5136/5554654170_663c600a32_q.jpg
# 130:download= https://live.staticflickr.com/1277/1356849035_bd9a456f99_q.jpg
# 131:download= https://live.staticflickr.com/5222/5554654614_af671589d6_q.jpg
# 132:download= https://live.staticflickr.com/2773/4152776296_1cfe60ee7c_q.jpg
# 133:download= https://live.staticflickr.com/2237/2470028798_cc290a8b45_q.jpg
# 134:download= https://live.staticflickr.com/4272/34811090805_1be82db49d_q.jpg
# 135:download= https://live.staticflickr.com/2755/4448014180_77b79ba471_q.jpg
# 136:download= https://live.staticflickr.com/1697/25108278040_d7d0353886_q.jpg
# 137:download= https://live.staticflickr.com/7099/6981087076_2177c4fa7c_q.jpg
# 138:download= https://live.staticflickr.com/6091/6340830931_707ddfee91_q.jpg
# 139:download= https://live.staticflickr.com/3825/13262818275_8b3c55ac94_q.jpg
# 140:download= https://live.staticflickr.com/7063/6937880139_8d6f3951c3_q.jpg
# 141:download= https://live.staticflickr.com/8697/17000176989_a85dc91e73_q.jpg
# 142:download= https://live.staticflickr.com/8158/7199902614_8acb99c543_q.jpg
# 143:download= https://live.staticflickr.com/8888/17637875684_7d984fc025_q.jpg
# 144:download= https://live.staticflickr.com/3106/2513664968_5d45a4901d_q.jpg
# 145:download= https://live.staticflickr.com/7459/8846841242_9f17acde88_q.jpg
# 146:download= https://live.staticflickr.com/1470/24424140725_1ced19f564_q.jpg
# 147:download= https://live.staticflickr.com/4268/34771400806_8b08535854_q.jpg
# 148:download= https://live.staticflickr.com/5136/5531822739_6116a2de80_q.jpg
# 149:download= https://live.staticflickr.com/4067/4543122102_fc6beb2b46_q.jpg
# 150:download= https://live.staticflickr.com/5138/5531823745_2944f2f6d9_q.jpg
# 151:download= https://live.staticflickr.com/5281/5278751015_a6c721503b_q.jpg
# 152:download= https://live.staticflickr.com/4227/34424877390_824123028a_q.jpg
# 153:download= https://live.staticflickr.com/4246/34771402916_89e8aceb1d_q.jpg
# 154:download= https://live.staticflickr.com/6001/5979751399_aa1c3cebbb_q.jpg
# 155:download= https://live.staticflickr.com/4122/4901698576_e43cb4702b_q.jpg
# 156:download= https://live.staticflickr.com/7714/28177765582_7ae7c0e467_q.jpg
# 157:download= https://live.staticflickr.com/2745/4484103176_0eed147db8_q.jpg
# 158:download= https://live.staticflickr.com/3333/3597612654_089d063c22_q.jpg
# 159:download= https://live.staticflickr.com/166/336674762_c549ba2125_q.jpg
# 160:download= https://live.staticflickr.com/2780/4444823770_626da93bba_q.jpg
# 161:download= https://live.staticflickr.com/4134/4930614469_9237f785cb_q.jpg
# 162:download= https://live.staticflickr.com/2882/8973476137_d108fb6cd9_q.jpg
# 163:download= https://live.staticflickr.com/8281/7696444254_c543aebd96_q.jpg
# 164:download= https://live.staticflickr.com/8222/29107937044_41223af209_q.jpg
# 165:download= https://live.staticflickr.com/7265/7696444722_d9f24129d1_q.jpg
# 166:download= https://live.staticflickr.com/746/32527685952_f1327306f5_q.jpg
# 167:download= https://live.staticflickr.com/8022/7696444096_628e57467c_q.jpg
# 168:download= https://live.staticflickr.com/4198/34001446413_0cba136e13_q.jpg
# 169:download= https://live.staticflickr.com/4245/34424887800_eb7f1de83f_q.jpg
# 170:download= https://live.staticflickr.com/8026/7696444568_d66cbfc8e3_q.jpg
# 171:download= https://live.staticflickr.com/7265/7696444418_b5c6cbdbb5_q.jpg
# 172:download= https://live.staticflickr.com/4222/34811108365_d1b22aae9f_q.jpg
# 173:download= https://live.staticflickr.com/4032/4390000928_b0b7b467d7_q.jpg
# 174:download= https://live.staticflickr.com/142/336674757_548d00055c_q.jpg
# 175:download= https://live.staticflickr.com/3159/2735445728_636e680271_q.jpg
# 176:download= https://live.staticflickr.com/4093/4881489932_fa973f0305_q.jpg
# 177:download= https://live.staticflickr.com/4028/4405146175_495bb47a5f_q.jpg
# 178:download= https://live.staticflickr.com/4248/33967971084_89eb1520d7_q.jpg
# 179:download= https://live.staticflickr.com/7119/7586487672_d684e879ac_q.jpg
# 180:download= https://live.staticflickr.com/4187/34771412846_4d0f9dba64_q.jpg
# 181:download= https://live.staticflickr.com/676/32914241543_9761586bc7_q.jpg
# 182:download= https://live.staticflickr.com/4177/34648602562_ebd041d7ff_q.jpg
# 183:download= https://live.staticflickr.com/4049/4270746647_1c9e2f3d4b_q.jpg
# 184:download= https://live.staticflickr.com/2803/4082196346_fa07a9447f_q.jpg
# 185:download= https://live.staticflickr.com/5684/22074413634_b4e5c7e3b8_q.jpg
# 186:download= https://live.staticflickr.com/5786/23117441460_932ee4fd81_q.jpg
# 187:download= https://live.staticflickr.com/290/32461889901_76392a2c27_q.jpg
# 188:download= https://live.staticflickr.com/4096/4762649708_690f9a848a_q.jpg
# 189:download= https://live.staticflickr.com/7321/12313030235_a744790aa0_q.jpg
# 190:download= https://live.staticflickr.com/5174/5519131022_7a41a67f22_q.jpg
# 191:download= https://live.staticflickr.com/2278/2344820055_24c8fd04c7_q.jpg
# 192:download= https://live.staticflickr.com/4040/4658387885_262c55684a_q.jpg
# 193:download= https://live.staticflickr.com/7122/7820320996_be09ffb109_q.jpg
# 194:download= https://live.staticflickr.com/376/32420847701_383b003d96_q.jpg
# 195:download= https://live.staticflickr.com/3625/3386137311_c3d86c9aae_q.jpg
# 196:download= https://live.staticflickr.com/8101/8659435810_3e7ba8c672_q.jpg
# 197:download= https://live.staticflickr.com/667/32420846991_5664f8f427_q.jpg
# 198:download= https://live.staticflickr.com/5808/30507448253_233031071b_q.jpg
# 199:download= https://live.staticflickr.com/4325/35888311251_814c8cb1b4_q.jpg
# 200:download= https://live.staticflickr.com/718/22520297700_215ec5cf35_q.jpg
# 201:download= https://live.staticflickr.com/6027/5960213877_2f218f656e_q.jpg
# 202:download= https://live.staticflickr.com/163/336674749_00e0820419_q.jpg
# 203:download= https://live.staticflickr.com/4118/4937568147_9e0c9b0a25_q.jpg
# 204:download= https://live.staticflickr.com/2939/33289311300_f0db3a9517_q.jpg
# 205:download= https://live.staticflickr.com/5469/31331100256_0e10355834_q.jpg
# 206:download= https://live.staticflickr.com/4017/4405146213_7500902a28_q.jpg
# 207:download= https://live.staticflickr.com/5312/14132670567_eee7811e6a_q.jpg
# 208:download= https://live.staticflickr.com/3698/12319206115_c932f5ebd0_q.jpg
# 209:download= https://live.staticflickr.com/2437/4489142158_53e8bf4ab2_q.jpg
# 210:download= https://live.staticflickr.com/7400/12318823533_859b41a992_q.jpg
# 211:download= https://live.staticflickr.com/5481/14318206144_f1a6b07e1a_q.jpg
# 212:download= https://live.staticflickr.com/8118/8658329411_c8388a4e7d_q.jpg
# 213:download= https://live.staticflickr.com/5266/5607381315_e2ee63d9d3_q.jpg
# 214:download= https://live.staticflickr.com/2861/12312348926_a9d550be4f_q.jpg
# 215:download= https://live.staticflickr.com/4040/4365264416_4837a55993_q.jpg
# 216:download= https://live.staticflickr.com/4051/4405146255_e433de5728_q.jpg
# 217:download= https://live.staticflickr.com/3793/14132477847_0134a00554_q.jpg
# 218:download= https://live.staticflickr.com/5788/31048563762_d7502d0ef3_q.jpg
# 219:download= https://live.staticflickr.com/2630/4152004353_c054954634_q.jpg
# 220:download= https://live.staticflickr.com/3632/3696794291_e1dd825cff_q.jpg
# 221:download= https://live.staticflickr.com/3762/14240848926_defe21f5c2_q.jpg
# 222:download= https://live.staticflickr.com/3822/14284238033_53d2d88d18_q.jpg
# 223:download= https://live.staticflickr.com/7365/12342487725_88bd0cb5c3_q.jpg
# 224:download= https://live.staticflickr.com/5512/12319057663_720dd61c8b_q.jpg
# 225:download= https://live.staticflickr.com/7551/16242420436_74016eea82_q.jpg
# 226:download= https://live.staticflickr.com/5480/14132534698_d78bc48d75_q.jpg
# 227:download= https://live.staticflickr.com/5721/29372863053_bd9f9acfb0_q.jpg
# 228:download= https://live.staticflickr.com/2907/14318858725_4a53171f23_q.jpg
# 229:download= https://live.staticflickr.com/4135/4901714840_20af0b17ee_q.jpg
# 230:download= https://live.staticflickr.com/3110/5745860455_76c44399c8_q.jpg
# 231:download= https://live.staticflickr.com/8116/8658331197_c38732472a_q.jpg
# 232:download= https://live.staticflickr.com/8401/8921956783_9715f729a0_q.jpg
# 233:download= https://live.staticflickr.com/2732/4172779391_bf3a7361b6_q.jpg
# 234:download= https://live.staticflickr.com/3731/11576160106_1d43644b05_q.jpg
# 235:download= https://live.staticflickr.com/6090/6095354143_b3f54db2b4_q.jpg
# 236:download= https://live.staticflickr.com/8126/8658329819_a9ffce5ed1_q.jpg
# 237:download= https://live.staticflickr.com/5598/30670795680_4c3b737e60_q.jpg
# 238:download= https://live.staticflickr.com/1024/4732449704_4cc53256da_q.jpg
# 239:download= https://live.staticflickr.com/2816/33652887611_fc293da6e1_q.jpg
# 240:download= https://live.staticflickr.com/2484/3882676027_690290b3e0_q.jpg
# 241:download= https://live.staticflickr.com/5337/7063256283_e655edec1d_q.jpg
# 242:download= https://live.staticflickr.com/8451/8042158313_4b08206762_q.jpg
# 243:download= https://live.staticflickr.com/3581/3643322001_b1b9c6320f_q.jpg
# 244:download= https://live.staticflickr.com/6025/5968545039_769ed673e6_q.jpg
# 245:download= https://live.staticflickr.com/7384/11575360205_773efcb710_q.jpg
# 246:download= https://live.staticflickr.com/5466/8885396317_878655dd2a_q.jpg
# 247:download= https://live.staticflickr.com/2778/4320876835_1acae0787f_q.jpg
# 248:download= https://live.staticflickr.com/3669/11511330544_a4d01b1cf4_q.jpg
# 249:download= https://live.staticflickr.com/1705/25702621723_5805c56029_q.jpg
# 250:download= https://live.staticflickr.com/1270/4608636460_a766b16521_q.jpg
# 251:download= https://live.staticflickr.com/4111/5091883739_d22271b5e4_q.jpg
# 252:download= https://live.staticflickr.com/7133/7428274830_bb6226a696_q.jpg
# 253:download= https://live.staticflickr.com/3360/3195982993_b5741ab236_q.jpg
# 254:download= https://live.staticflickr.com/4009/4603302778_3a1823a4b2_q.jpg
# 255:download= https://live.staticflickr.com/7064/6886127113_d687dcc22f_q.jpg
# 256:download= https://live.staticflickr.com/7475/16084012809_4b16132c9f_q.jpg
# 257:download= https://live.staticflickr.com/4072/4625330055_1cdfdcf978_q.jpg
# 258:download= https://live.staticflickr.com/5821/20590353593_d0f712a464_q.jpg
# 259:download= https://live.staticflickr.com/5618/21614937580_7722405b88_q.jpg
# 260:download= https://live.staticflickr.com/5284/5358621205_98507d261d_q.jpg
# 261:download= https://live.staticflickr.com/129/336674754_48b7f13f81_q.jpg
# 262:download= https://live.staticflickr.com/5544/11576176746_a80fc4650e_q.jpg
# 263:download= https://live.staticflickr.com/5241/5297264619_83eab47856_q.jpg
# 264:download= https://live.staticflickr.com/4042/4373463236_da350a2c69_q.jpg
# 265:download= https://live.staticflickr.com/5325/7111480601_2b6f06e8b9_q.jpg
# 266:download= https://live.staticflickr.com/8152/7661749748_9737e37c3f_q.jpg
# 267:download= https://live.staticflickr.com/7252/7661748966_8757332b36_q.jpg
# 268:download= https://live.staticflickr.com/3675/9728905310_68257d958f_q.jpg
# 269:download= https://live.staticflickr.com/8586/15608230893_c15ff85f73_q.jpg
# 270:download= https://live.staticflickr.com/2706/4251048770_f8b1662322_q.jpg
# 271:download= https://live.staticflickr.com/3042/3411156500_8bb92631fa_q.jpg
# 272:download= https://live.staticflickr.com/6027/5956870916_3977bc2b61_q.jpg
# 273:download= https://live.staticflickr.com/7111/7661748368_6506b60620_q.jpg
# 274:download= https://live.staticflickr.com/5150/5636854624_8aa1f3b5d2_q.jpg
# 275:download= https://live.staticflickr.com/8163/7661748604_06b493a7c8_q.jpg
# 276:download= https://live.staticflickr.com/5479/11575715424_d7701b0f81_q.jpg
# 277:download= https://live.staticflickr.com/1462/24359847792_1857d7808a_q.jpg
# 278:download= https://live.staticflickr.com/8433/7661749378_a30b91c49a_q.jpg
# 279:download= https://live.staticflickr.com/7170/6423147825_099cb770bd_q.jpg
# 280:download= https://live.staticflickr.com/5742/30446648686_f3a9602c0a_q.jpg
# 281:download= https://live.staticflickr.com/2056/5775961067_617d8c79c5_q.jpg
# 282:download= https://live.staticflickr.com/2496/4200056245_969feb4927_q.jpg
# 283:download= https://live.staticflickr.com/8423/7661750038_a53e68b6c4_q.jpg
# 284:download= https://live.staticflickr.com/729/21461888314_8497f08d70_q.jpg
# 285:download= https://live.staticflickr.com/2582/4039241828_356eff06b4_q.jpg
# 286:download= https://live.staticflickr.com/3786/12247368984_1ff202bd46_q.jpg
# 287:download= https://live.staticflickr.com/4171/34525167315_bde8b1ba14_q.jpg
# 288:download= https://live.staticflickr.com/105/312838675_2c0bc560b6_q.jpg
# 289:download= https://live.staticflickr.com/5052/5546163139_30ac023bbb_q.jpg
# 290:download= https://live.staticflickr.com/5016/5391651393_3b7c407ac8_q.jpg
# 291:download= https://live.staticflickr.com/662/22737894359_cc9c07b923_q.jpg
# 292:download= https://live.staticflickr.com/2834/32951618204_6a37075464_q.jpg
# 293:download= https://live.staticflickr.com/3167/2976368409_a36c9ec3b1_q.jpg
# 294:download= https://live.staticflickr.com/7208/7000028235_38db690c2f_q.jpg
# 295:download= https://live.staticflickr.com/3716/19588340049_7d118ca5f0_q.jpg
# 296:download= https://live.staticflickr.com/1914/44462517865_ab6016fb6e_q.jpg
# 297:download= https://live.staticflickr.com/1686/25776349616_7f290e5e36_q.jpg
# 298:download= https://live.staticflickr.com/2767/4304713643_e7e820da56_q.jpg
# 299:download= https://live.staticflickr.com/4094/4868617756_db39d6852d_q.jpg
# 300:download= https://live.staticflickr.com/5008/5210903071_b274afec24_q.jpg

# %%
import numpy as np
from PIL import Image
import os, glob, random

outfile = "image/photos.npz"
max_photo = 100
photo_size = 32
x = []
y = []

def main():
    glob_files("./image/sushi",0)
    glob_files("./image/salad",1)
    glob_files("./image/pizza",2)
    glob_files("./image/tteokbokki",3)
    glob_files("./image/kimbap",4)
    glob_files("./image/jjajang",5)
    glob_files("./image/hamburger",6)
    glob_files("./image/pasta",7)
    glob_files("./image/tonkatsu",7)
    
    np.savez(outfile, x=x, y=y)
    print("저장했습니다.:" + outfile, len(x))
    
def glob_files(path, label):
    files = glob.glob(path + "/*.jpg")
    random.shuffle(files)
    
    num = 0 
    for f in files:
        if num >= max_photo: break
        num += 1
        
        img = Image.open(f)
        img = img.convert("RGB")
        img = img.resize((photo_size, photo_size))
        img = np.asarray(img)
        x.append(img)
        y.append(label)

if __name__ == '__main__':
    main()
# Out:
# 저장했습니다.:image/photos.npz 800

# %%
import matplotlib.pyplot as plt
# 사진 데이터 읽어 들이기
photos=np.load('image/photos.npz')
x=photos['x']
y=photos['y']
idx=0
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.title(y[i+idx])
    plt.imshow(x[i+idx])
plt.show()

# %%
# !pip install keras
# !pip install kears.models
# !pip install kears.layers
# !pip install kears.optimizers

# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.9.1-cp39-cp39-macosx_10_14_x86_64.whl (228.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.5/228.5 MB 2.3 MB/s eta 0:00:0000:0100:02
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.46.3-cp39-cp39-macosx_10_10_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 4.7 MB/s eta 0:00:0000:0100:01
# Collecting libclang>=13.0.0
#   Downloading libclang-14.0.1-py2.py3-none-macosx_10_9_x86_64.whl (13.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 3.9 MB/s eta 0:00:0000:0100:01
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.8 MB/s eta 0:00:00
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.7 MB/s eta 0:00:00
# Collecting tensorboard<2.10,>=2.9
#   Downloading tensorboard-2.9.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 4.6 MB/s eta 0:00:0000:0100:01
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.4-cp39-cp39-macosx_10_9_x86_64.whl (961 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.7/961.7 kB 3.8 MB/s eta 0:00:00a 0:00:01
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 4.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: six>=1.12.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: packaging in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (21.0)
# Requirement already satisfied: numpy>=1.20 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.20.3)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting keras<2.10.0,>=2.9.0rc0
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 4.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: wrapt>=1.11.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.12.1)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.0.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.7/126.7 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: h5py>=2.9.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.2.1)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.26.0-cp39-cp39-macosx_10_14_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 3.0 MB/s eta 0:00:0000:0100:01
# Collecting flatbuffers<2,>=1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: setuptools in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 kB 2.3 MB/s eta 0:00:00a 0:00:01
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.6.6-py2.py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.7/156.7 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.0.2)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 3.3 MB/s eta 0:00:0000:0100:01
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 3.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.26.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from packaging->tensorflow) (3.0.4)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 2.9 MB/s eta 0:00:00a 0:00:01
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.2)
# Requirement already satisfied: zipp>=0.5 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.6.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/yunjiin/opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4847 sha256=863c22467b33c7793b1d2ec8bf477c1a16199391f4adbe7d663f7d5ea32395e5
#   Stored in directory: /Users/yunjiin/Library/Caches/pip/wheels/b6/0d/90/0d1bbd99855f99cb2f6c2e5ff96f8023fad8ec367695f7d72d
# Successfully built termcolor
# Installing collected packages: termcolor, tensorboard-plugin-wit, pyasn1, libclang, keras, flatbuffers, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, pyasn1-modules, protobuf, opt-einsum, keras-preprocessing, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, markdown, google-auth, google-auth-oauthlib, tensorboard, tensorflow
# Successfully installed absl-py-1.0.0 astunparse-1.6.3 cachetools-5.2.0 flatbuffers-1.12 gast-0.4.0 google-auth-2.6.6 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.46.3 keras-2.9.0 keras-preprocessing-1.1.2 libclang-14.0.1 markdown-3.3.7 opt-einsum-3.3.0 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 rsa-4.8 tensorboard-2.9.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.9.1 tensorflow-estimator-2.9.0 tensorflow-io-gcs-filesystem-0.26.0 termcolor-1.1.0

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import RMSprop

# CNN 모델 정의하기
def def_model(in_shape, nb_classes):
    model=Sequential()
    model.add(Conv2D(32,
                    kernel_size=(3,3),
                    activation='relu',
                    input_shape=in_shape))
    model.add(Conv2D(32,(3,3),activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))
    
    model.add(Conv2D(64,(3,3),activation='relu'))
    model.add(Conv2D(64,(3,3),activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))
    
    model.add(Flatten())
    model.add(Dense(512,activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(nb_classes,activation='softmax'))
    return model

# %%
# compile & return model
def get_model(in_shape, nb_classes):
    model=def_model(in_shape,nb_classes)
    model.compile(
        loss='categorical_crossentropy',
        optimizer=RMSprop(),
        metrics=['accuracy'])
    return model

# %%
# import cnn_model
import keras
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

im_rows=32
im_cols=32
im_color=3
in_shape=(im_rows,im_cols,im_color)
nb_classes=3

photos=np.load('image/photos.npz')
x=photos['x']
y=photos['y']

x=x.reshape(-1,im_rows,im_cols,im_color)
x=x.astype('float32')/255
y=keras.utils.np_utils.to_categorical(y.astype('int32'),nb_classes)

x_train, x_test, y_train, y_test=train_test_split(
x,y,train_size=0.8)

# CNN model 만들기
model=get_model(in_shape,nb_classes)

hist=model.fit(x_train,y_train,
               batch_size=32,
               epochs=20,
               verbose=1,
               validation_data=(x_test,y_test)
              )

score=model.evaluate(x_test,y_test,verbose=1)
print('정답률=',score[1],'손실률=',score[0])
# Out:
# Epoch 1/20
# 7/7 [==============================] - 2s 146ms/step - loss: 1.2555 - accuracy: 0.3439 - val_loss: 1.0940 - val_accuracy: 0.3393
# Epoch 2/20
# 7/7 [==============================] - 1s 96ms/step - loss: 1.0947 - accuracy: 0.3620 - val_loss: 1.1095 - val_accuracy: 0.3750
# Epoch 3/20
# 7/7 [==============================] - 1s 96ms/step - loss: 1.0815 - accuracy: 0.4072 - val_loss: 1.1090 - val_accuracy: 0.4286
# Epoch 4/20
# 7/7 [==============================] - 1s 93ms/step - loss: 1.0629 - accuracy: 0.4027 - val_loss: 1.0524 - val_accuracy: 0.4821
# Epoch 5/20
# 7/7 [==============================] - 1s 99ms/step - loss: 1.0722 - accuracy: 0.4615 - val_loss: 1.0162 - val_accuracy: 0.5179
# Epoch 6/20
# 7/7 [==============================] - 1s 96ms/step - loss: 1.0516 - accuracy: 0.4661 - val_loss: 1.0344 - val_accuracy: 0.5179
# Epoch 7/20
# 7/7 [==============================] - 1s 95ms/step - loss: 0.9757 - accuracy: 0.5249 - val_loss: 1.2367 - val_accuracy: 0.4286
# Epoch 8/20
# 7/7 [==============================] - 1s 94ms/step - loss: 1.0114 - accuracy: 0.5158 - val_loss: 1.0492 - val_accuracy: 0.4821
# Epoch 9/20
# 7/7 [==============================] - 1s 102ms/step - loss: 1.0131 - accuracy: 0.4977 - val_loss: 1.0103 - val_accuracy: 0.4821
# Epoch 10/20
# 7/7 [==============================] - 1s 98ms/step - loss: 0.9383 - accuracy: 0.5656 - val_loss: 0.9438 - val_accuracy: 0.5536
# Epoch 11/20
# 7/7 [==============================] - 1s 97ms/step - loss: 0.8974 - accuracy: 0.5475 - val_loss: 0.9646 - val_accuracy: 0.5179
# Epoch 12/20
# 7/7 [==============================] - 1s 107ms/step - loss: 0.8454 - accuracy: 0.6199 - val_loss: 1.2529 - val_accuracy: 0.4107
# Epoch 13/20
# 7/7 [==============================] - 1s 100ms/step - loss: 0.9309 - accuracy: 0.5792 - val_loss: 1.1087 - val_accuracy: 0.4286
# Epoch 14/20
# 7/7 [==============================] - 1s 103ms/step - loss: 0.8553 - accuracy: 0.5747 - val_loss: 1.0327 - val_accuracy: 0.5357
# Epoch 15/20
# 7/7 [==============================] - 1s 107ms/step - loss: 0.7201 - accuracy: 0.6606 - val_loss: 1.1330 - val_accuracy: 0.5000
# Epoch 16/20
# 7/7 [==============================] - 1s 102ms/step - loss: 0.6962 - accuracy: 0.6652 - val_loss: 1.0168 - val_accuracy: 0.5536
# Epoch 17/20
# 7/7 [==============================] - 1s 101ms/step - loss: 0.8404 - accuracy: 0.6380 - val_loss: 1.0483 - val_accuracy: 0.5714
# Epoch 18/20
# 7/7 [==============================] - 1s 99ms/step - loss: 0.5739 - accuracy: 0.7421 - val_loss: 1.1416 - val_accuracy: 0.3750
# Epoch 19/20
# 7/7 [==============================] - 1s 132ms/step - loss: 0.5956 - accuracy: 0.7330 - val_loss: 1.1358 - val_accuracy: 0.4643
# Epoch 20/20
# 7/7 [==============================] - 1s 105ms/step - loss: 0.5402 - accuracy: 0.7964 - val_loss: 1.3683 - val_accuracy: 0.4643
# 2/2 [==============================] - 0s 16ms/step - loss: 1.3683 - accuracy: 0.4643
# 정답률= 0.4642857015132904 손실률= 1.3683406114578247

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train','test'],loc='upper left')
plt.show()


plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train','test'],loc='upper left')
plt.show()

model.save_weights('./image/photos-model-light.hdf5')

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.5.5.64-cp36-abi3-win_amd64.whl (35.4 MB)
#      ---------------------------------------- 35.4/35.4 MB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in c:\users\khl35\appdata\local\programs\python\python310\lib\site-packages (from opencv-python) (1.22.2)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.5.64

# %%
import matplotlib.pyplot as plt
import cv2

photos = np.load('image/photos.npz')
x = photos['x']
img = x[12]

plt.figure(figsize= (10,10))
for i in range(36):
    plt.subplot(6,6,i+1)

    center = (16,16)
    angle = i * 5
    scale = 1.0
    mtx = cv2.getRotationMatrix2D(center, angle, scale)
    img2 = cv2.warpAffine(img, mtx, (32, 32))
    
    plt.imshow(img2)
plt.show()

# %%
import cv2

x_train, x_test, y_train, y_test = train_test_split( x, y, train_size=0.8)

x_new = []
y_new = []

for i, xi in enumerate(x_train):
    yi = y_train[i]
    for ang in range(-30, 30, 5):
        center = (16,16)
        mtx = cv2.getRotationMatrix2D(center, ang, 1.0)
        xi2 = cv2.warpAffine(xi, mtx, (32,32))
        x_new.append(xi2)
        y_new.append(yi)
        
        xi3 = cv2.flip(xi2, 1)

print('수량 늘리기 전 = ', len(y_train) )
x_train = np.array(x_new)
y_train = np.array(y_new)
print('수량을 늘린 후 = ', len(y_train))

model = get_model(in_shape, nb_classes)
# Out:
# 수량 늘리기 전 =  221
# 수량을 늘린 후 =  2652

# %%
# import cnn_model
import keras
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

target_image = "test-sushi.jgp"

im_rows = 32
im_cols = 32
im_color = 3
in_shape = (im_rows, im_cols, im_color)
nb_classes = 3

LABELS = ["초밥", "샐러드", "마파두부"]

CALORIES = [588, 118, 648]

model = get_model(in_shape, nb_classes)
model.load_weights('./image/photos-model-light.hdf5')

def check_photo(path):
    img = Image.open(path)
    img = img.convert("RGB")
    img = img.resize((im_cols, im_rows))
    plt.imshow(img)
    plt.show()
    
    x = np.asarray(img)
    x = x.reshape(-1, im_rows, im_cols, im_color) 
    x = x/ 255
    
    pre = model.predict([x])[0]
    idx = pre.argmax()
    per = int(pre[idx]*100)
    return (idx, per)

def check_photo_str(path):
    idx, per = check_photo(path)
    
    print("이 사진은 ", LABELS[idx], "로(으로), 칼로리는 ", CALORIES[idx], "kcal 입니다.")
    print("정확도는 ", per , "% 입니다.")
    
if __name__ == '__main__':
    check_photo_str('./image/test_sushi.jpg')
#     check_photo_str('test_salad.jpg')
# Out:
# 1/1 [==============================] - 0s 213ms/step
# 이 사진은  샐러드 로(으로), 칼로리는  118 kcal 입니다.
# 정확도는  97 % 입니다.
